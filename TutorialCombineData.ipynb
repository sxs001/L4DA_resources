# %% [markdown]
# <a href="https://colab.research.google.com/github/tdmhub/L4DA_resources/blob/main/TutorialCombineData.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. Set up

# %%
# Importing library
import pandas as pd
# Set numbers for how many rows and columns will be displayed
pd.set_option('display.min_rows', 10) #default will be 10
pd.set_option('display.max_columns', 20)

# %% [markdown]
# 2. Loading Excel
#  Formats Into a Pandas Data Frame
#
#  The first Excel sheet contains the details about the items in each order
#  The second Excel Sheet contains the details about the reps.

# %%
url='https://github.com/tdmhub/L4DA_resources/raw/main/OrderItemV1.xlsx'
df_Item = pd.read_excel(url, sheet_name='Sheet1')
df_Item
# Out:
#     Order No     Item  Units  UnitCost    Total
# 0          1   Pencil     95      1.99   189.05
# 1          2   Binder     50     19.99   999.50
# 2          3   Pencil     36      4.99   179.64
# 3          4      Pen     27     19.99   539.73
# 4          5   Pencil     56      2.99   167.44
# 5          6   Binder     60      4.99   299.40
# 6          7   Pencil     75      1.99   149.25
# 7          8   Pencil     90      4.99   449.10
# 8          9   Pencil     32      1.99    63.68
# 9         10   Binder     60      8.99   539.40
# 10        11   Pencil     90      4.99   449.10
# 11        12   Binder     29      1.99    57.71
# 12        13   Binder     81     19.99  1619.19
# 13        14   Pencil     35      4.99   174.65
# 14        15     Desk      2    125.00   250.00
# 15        16  Pen Set     16     15.99   255.84
# 16        17   Binder     28      8.99   251.72
# 17        18      Pen     64      8.99   575.36
# 18        19      Pen     15     19.99   299.85
# ...

# %%
url='https://github.com/tdmhub/L4DA_resources/raw/main/OrderRepV1A.xlsx'
df_Rep = pd.read_excel(url, sheet_name='Sheet1')
df_Rep
# Out:
#     Order No  OrderDate   Region       Rep
# 0          1 2019-01-06     East     Jones
# 1          2 2019-01-23  Central    Kivell
# 2          3 2019-02-09  Central   Jardine
# 3          4 2019-02-26  Central      Gill
# 4          5 2019-03-15     West   Sorvino
# 5          6 2019-04-01     East     Jones
# 6          7 2019-04-18  Central   Andrews
# 7          8 2019-05-05  Central   Jardine
# 8          9 2019-05-22     West  Thompson
# 9         10 2019-06-08     East     Jones
# 10        11 2019-06-25  Central    Morgan
# 11        12 2019-07-12     East    Howard
# 12        13 2019-07-29     East    Parent
# 13        14 2019-08-15     East     Jones
# 14        15 2019-09-01  Central     Smith
# 15        16 2019-09-18     East     Jones
# 16        17 2019-10-05  Central    Morgan
# 17        18 2019-10-22     East     Jones
# 18        19 2019-11-08     East    Parent
# 19        20 2019-11-25  Central    Kivell
# 20        21 2019-12-12  Central     Smith
# ...

# %% [markdown]
# Combine the Data Frames  join='outer'
# The common column is Order number, so the join is made on this column.

# %%
df_ItemRep= pd.merge(df_Item,df_Rep, on='Order No')
df_ItemRep
# Out:
#     Order No     Item  Units  UnitCost    Total  OrderDate   Region       Rep
# 0          1   Pencil     95      1.99   189.05 2019-01-06     East     Jones
# 1          2   Binder     50     19.99   999.50 2019-01-23  Central    Kivell
# 2          3   Pencil     36      4.99   179.64 2019-02-09  Central   Jardine
# 3          4      Pen     27     19.99   539.73 2019-02-26  Central      Gill
# 4          5   Pencil     56      2.99   167.44 2019-03-15     West   Sorvino
# 5          6   Binder     60      4.99   299.40 2019-04-01     East     Jones
# 6          7   Pencil     75      1.99   149.25 2019-04-18  Central   Andrews
# 7          8   Pencil     90      4.99   449.10 2019-05-05  Central   Jardine
# 8          9   Pencil     32      1.99    63.68 2019-05-22     West  Thompson
# 9         10   Binder     60      8.99   539.40 2019-06-08     East     Jones
# 10        11   Pencil     90      4.99   449.10 2019-06-25  Central    Morgan
# ...

# %% [markdown]
# Drop rows with NAN

# %%
df_ItemRep2=df_ItemRep.dropna()
df_ItemRep2
# Out:
#     Order No     Item  Units  UnitCost    Total  OrderDate   Region       Rep
# 0          1   Pencil     95      1.99   189.05 2019-01-06     East     Jones
# 1          2   Binder     50     19.99   999.50 2019-01-23  Central    Kivell
# 2          3   Pencil     36      4.99   179.64 2019-02-09  Central   Jardine
# 3          4      Pen     27     19.99   539.73 2019-02-26  Central      Gill
# 4          5   Pencil     56      2.99   167.44 2019-03-15     West   Sorvino
# 5          6   Binder     60      4.99   299.40 2019-04-01     East     Jones
# 6          7   Pencil     75      1.99   149.25 2019-04-18  Central   Andrews
# 7          8   Pencil     90      4.99   449.10 2019-05-05  Central   Jardine
# 8          9   Pencil     32      1.99    63.68 2019-05-22     West  Thompson
# 9         10   Binder     60      8.99   539.40 2019-06-08     East     Jones
# 10        11   Pencil     90      4.99   449.10 2019-06-25  Central    Morgan
# ...

# %% [markdown]
# Create a data frame holding the data for all the reps in the East region and clean and process this data to find the total sales for each rep.

# %%
df_ItemRepEast=df_ItemRep2.where(df_ItemRep2.Region=='East')
df_ItemRepEast2=df_ItemRepEast.dropna()
df_ItemRepEast2
# Out:
#     Order No     Item  Units  UnitCost    Total  OrderDate Region     Rep
# 0        1.0   Pencil   95.0      1.99   189.05 2019-01-06   East   Jones
# 5        6.0   Binder   60.0      4.99   299.40 2019-04-01   East   Jones
# 9       10.0   Binder   60.0      8.99   539.40 2019-06-08   East   Jones
# 11      12.0   Binder   29.0      1.99    57.71 2019-07-12   East  Howard
# 12      13.0   Binder   81.0     19.99  1619.19 2019-07-29   East  Parent
# 13      14.0   Pencil   35.0      4.99   174.65 2019-08-15   East   Jones
# 15      16.0  Pen Set   16.0     15.99   255.84 2019-09-18   East   Jones
# 17      18.0      Pen   64.0      8.99   575.36 2019-10-22   East   Jones
# 18      19.0      Pen   15.0     19.99   299.85 2019-11-08   East  Parent
# 21      22.0  Pen Set   74.0     15.99  1183.26 2019-12-29   East  Parent
# 24      25.0   Binder    4.0      4.99    19.96 2020-02-18   East   Jones
# 28      29.0      Pen   96.0      4.99   479.04 2020-04-27   East  Howard
# ...

# %%
df_ItemRepEast3=df_ItemRepEast2.pivot(index='Order No',columns='Rep',values='Total')
df_ItemRepEast3
# Out:
# Rep       Howard   Jones   Parent
# Order No
# 1.0          NaN  189.05      NaN
# 6.0          NaN  299.40      NaN
# 10.0         NaN  539.40      NaN
# 12.0       57.71     NaN      NaN
# 13.0         NaN     NaN  1619.19
# 14.0         NaN  174.65      NaN
# 16.0         NaN  255.84      NaN
# 18.0         NaN  575.36      NaN
# 19.0         NaN     NaN   299.85
# 22.0         NaN     NaN  1183.26
# 25.0         NaN   19.96      NaN
# 29.0      479.04     NaN      NaN
# 33.0         NaN  309.38      NaN

# %%
df_ItemRepEast4=df_ItemRepEast3.fillna(0)
df_ItemRepEast4
# Out:
# Rep       Howard   Jones   Parent
# Order No
# 1.0         0.00  189.05     0.00
# 6.0         0.00  299.40     0.00
# 10.0        0.00  539.40     0.00
# 12.0       57.71    0.00     0.00
# 13.0        0.00    0.00  1619.19
# 14.0        0.00  174.65     0.00
# 16.0        0.00  255.84     0.00
# 18.0        0.00  575.36     0.00
# 19.0        0.00    0.00   299.85
# 22.0        0.00    0.00  1183.26
# 25.0        0.00   19.96     0.00
# 29.0      479.04    0.00     0.00
# 33.0        0.00  309.38     0.00

# %%
df_Eastsum=df_ItemRepEast4.sum()
df_Eastsum
# Out:
# Rep
# Howard     536.75
# Jones     2363.04
# Parent    3102.30
# dtype: float64

# %% [markdown]
# Repeat the processing above for the West and Central regions to find the total sales for each rep in these regions.

# %%
df_ItemRepWest=df_ItemRep2.where(df_ItemRep2.Region=='West')
df_ItemRepWest2=df_ItemRepWest.dropna()
df_ItemRepWest2
# Out:
#     Order No    Item  Units  UnitCost    Total  OrderDate Region       Rep
# 4        5.0  Pencil   56.0      2.99   167.44 2019-03-15   West   Sorvino
# 8        9.0  Pencil   32.0      1.99    63.68 2019-05-22   West  Thompson
# 25      26.0  Binder    7.0     19.99   139.93 2020-03-07   West   Sorvino
# 35      36.0    Desk    3.0    275.00   825.00 2020-08-24   West   Sorvino
# 37      38.0     Pen   76.0      1.99   151.24 2020-09-27   West   Sorvino
# 38      39.0  Binder   57.0     19.99  1139.43 2020-10-14   West  Thompson

# %%
df_ItemRepCentral=df_ItemRep2.where(df_ItemRep2.Region=='Central')
df_ItemRepCentral2=df_ItemRepCentral.dropna()
df_ItemRepCentral2
# Out:
#     Order No     Item  Units  UnitCost    Total  OrderDate   Region      Rep
# 1        2.0   Binder   50.0     19.99   999.50 2019-01-23  Central   Kivell
# 2        3.0   Pencil   36.0      4.99   179.64 2019-02-09  Central  Jardine
# 3        4.0      Pen   27.0     19.99   539.73 2019-02-26  Central     Gill
# 6        7.0   Pencil   75.0      1.99   149.25 2019-04-18  Central  Andrews
# 7        8.0   Pencil   90.0      4.99   449.10 2019-05-05  Central  Jardine
# 10      11.0   Pencil   90.0      4.99   449.10 2019-06-25  Central   Morgan
# 14      15.0     Desk    2.0    125.00   250.00 2019-09-01  Central    Smith
# 16      17.0   Binder   28.0      8.99   251.72 2019-10-05  Central   Morgan
# 19      20.0  Pen Set   96.0      4.99   479.04 2019-11-25  Central   Kivell
# 20      21.0   Pencil   67.0      1.29    86.43 2019-12-12  Central    Smith
# 22      23.0   Binder   46.0      8.99   413.54 2020-01-15  Central     Gill
# ...

# %% [markdown]
# You are now to append the three saparate tables for East, West and Central together.

# %%
df_Original=pd.concat([df_ItemRepCentral2,df_ItemRepEast2,df_ItemRepWest2])
df_OriginalSorted=df_Original.sort_values('Order No')
df_OriginalSorted
# Out:
#     Order No     Item  Units  UnitCost    Total  OrderDate   Region       Rep
# 0        1.0   Pencil   95.0      1.99   189.05 2019-01-06     East     Jones
# 1        2.0   Binder   50.0     19.99   999.50 2019-01-23  Central    Kivell
# 2        3.0   Pencil   36.0      4.99   179.64 2019-02-09  Central   Jardine
# 3        4.0      Pen   27.0     19.99   539.73 2019-02-26  Central      Gill
# 4        5.0   Pencil   56.0      2.99   167.44 2019-03-15     West   Sorvino
# 5        6.0   Binder   60.0      4.99   299.40 2019-04-01     East     Jones
# 6        7.0   Pencil   75.0      1.99   149.25 2019-04-18  Central   Andrews
# 7        8.0   Pencil   90.0      4.99   449.10 2019-05-05  Central   Jardine
# 8        9.0   Pencil   32.0      1.99    63.68 2019-05-22     West  Thompson
# 9       10.0   Binder   60.0      8.99   539.40 2019-06-08     East     Jones
# 10      11.0   Pencil   90.0      4.99   449.10 2019-06-25  Central    Morgan
# ...
