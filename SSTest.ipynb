# %% [markdown]
# <a href="https://colab.research.google.com/github/tdmhub/L4DA_resources/blob/main/SSTest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# we can set numbers for how many rows and columns will be displayed
pd.set_option('display.min_rows', 10) #default will be 10
pd.set_option('display.max_columns', 20)

url=' https://raw.githubusercontent.com/tdmhub/L4DA_resources/main/StudentsMarkCorrCoeff.xlsx'

# Command Andy Brown - this opens the sheet called Marks
df_Marks = pd.read_excel(url, sheet_name='Marks')
df_Marks
# Out:
#     Unnamed: 0    Unnamed: 1      Unnamed: 2      Unnamed: 3      Unnamed: 4  \
# 0          NaN           NaN             NaN             NaN             NaN
# 1          NaN           NaN  Revision hours  Month of Birth  Classes Missed
# 2          NaN            S1              18               1               3
# 3          NaN            S2               2               9              30
# 4          NaN            S3              13              10              20
# 5          NaN            S4              14               3               7
# 6          NaN            S5               6               2              24
# 7          NaN            S6              15              11               1
# 8          NaN            S7              16               4               5
# 9          NaN            S8               9               6              16
# 10         NaN            S9              10               7              10
# ...
